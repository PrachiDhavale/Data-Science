# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r'C:\Users\admin\Desktop\California House Price.csv')

# %%
dataset
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
x = dataset[['longitude','latitude','housing_median_age','total_rooms','total_bedrooms','population','households','median_income','ocean_proximity']]
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
y = dataset[['median_house_value']]
y
# Out:
#        median_house_value
# 0                  452600
# 1                  358500
# 2                  352100
# 3                  341300
# 4                  342200
# ...                   ...
# 20635               78100
# 20636               77100
# 20637               92300
# 20638               84700
# 20639               89400
#
# [20640 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
import numpy as np

# Encode the 'ocean_proximity' column
labelencoder_x = LabelEncoder()
x[:, 8] = labelencoder_x.fit_transform(x[:, 8])

# Create a ColumnTransformer to apply OneHotEncoder to the 'ocean_proximity' column
ct = ColumnTransformer(
    [("ocean_proximity", OneHotEncoder(), [8])],
    remainder='passthrough'
)

# Fit and transform, then convert to dense array
x_transformed = ct.fit_transform(x).toarray()

# Proceed with your model training and prediction as needed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       5 # Encode the 'ocean_proximity' column
#       6 labelencoder_x = LabelEncoder()
# ----> 7 x[:, 8] = labelencoder_x.fit_transform(x[:, 8])
#       9 # Create a ColumnTransformer to apply OneHotEncoder to the 'ocean_proximity' column
#      10 ct = ColumnTransformer(
#      11     [("ocean_proximity", OneHotEncoder(), [8])],
#      12     remainder='passthrough'
#      13 )
#
# NameError: name 'x' is not defined

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size = .8, random_state = 0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
print(x_test)
print(y_test)
